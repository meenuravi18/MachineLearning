# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("cleaned_data.csv")
data.head()
# Out:
#    len_title  len_abstract  num_authors  num_conflicts  num_tags  \
# 0         10           127            4              2         1
# 1          7            95            2              1         2
# 2          3           250            6              2         2
# 3          4           147            2              2         3
# 4          7           158            2              3         1
#
#    num_ivy_conflicts  num_big_four_conflicts  num_keywords_abstract  \
# 0                  0                       0                      2
# 1                  0                       0                      1
# 2                  0                       0                      1
# 3                  0                       0                      1
# 4                  0                       0                      1
#
#    num_keywords_title  num_pages  num_sections    decision
# 0                   0         11             9  Not Accept
# 1                   0         11             8      Accept
# 2                   0         15            12      Accept
# 3                   0         15            15      Accept
# 4                   0         14            10      Accept

# %% [markdown]
# ### EDA

# %%
data.shape

# %%
missing_values=data.isna().sum()
full=len(data)
percent=(missing_values/full)*100
percent

# %%
data.describe()

# %%
data.dtypes

# %%
duplicate_rows = data[data.duplicated()]
print("Duplicate rows: ", duplicate_rows.shape)

# %%
for i in list(data.columns):
    data[i].hist()
    plt.title(i)
    plt.show()

# %%
for i in list(data.columns):
    if i!="decision":
        data[i].plot()
        plt.title(i)
        plt.show()

# %%
display(round(data.corr(),2))
sns.pairplot(data)
plt.show()
# Out:
#                         len_title  len_abstract  num_authors  num_conflicts  \
# len_title                    1.00          0.07         0.03           0.07
# len_abstract                 0.07          1.00         0.14           0.14
# num_authors                  0.03          0.14         1.00           0.26
# num_conflicts                0.07          0.14         0.26           1.00
# num_tags                     0.02         -0.02         0.02          -0.00
# num_ivy_conflicts           -0.01          0.02        -0.02           0.03
# num_big_four_conflicts      -0.12          0.01         0.10          -0.10
# num_keywords_abstract        0.05          0.18         0.06           0.03
# num_keywords_title          -0.03         -0.02        -0.10          -0.04
# num_pages                   -0.08          0.13         0.07          -0.01
# num_sections                -0.09          0.03         0.06           0.05
#
#                         num_tags  num_ivy_conflicts  num_big_four_conflicts  \
# len_title                   0.02              -0.01                   -0.12
# len_abstract               -0.02               0.02                    0.01
# num_authors                 0.02              -0.02                    0.10
# num_conflicts              -0.00               0.03                   -0.10
# num_tags                    1.00              -0.07                    0.02
# num_ivy_conflicts          -0.07               1.00                   -0.05
# num_big_four_conflicts      0.02              -0.05                    1.00
# num_keywords_abstract      -0.01               0.08                    0.03
# num_keywords_title          0.06              -0.02                   -0.05
# num_pages                   0.08               0.06                    0.13
# num_sections                0.07              -0.02                    0.04
#
#                         num_keywords_abstract  num_keywords_title  num_pages  \
# len_title                                0.05               -0.03      -0.08
# len_abstract                             0.18               -0.02       0.13
# num_authors                              0.06               -0.10       0.07
# num_conflicts                            0.03               -0.04      -0.01
# num_tags                                -0.01                0.06       0.08
# num_ivy_conflicts                        0.08               -0.02       0.06
# num_big_four_conflicts                   0.03               -0.05       0.13
# num_keywords_abstract                    1.00                0.09      -0.02
# num_keywords_title                       0.09                1.00      -0.04
# num_pages                               -0.02               -0.04       1.00
# num_sections                            -0.03               -0.01       0.36
#
#                         num_sections
# len_title                      -0.09
# len_abstract                    0.03
# num_authors                     0.06
# num_conflicts                   0.05
# num_tags                        0.07
# num_ivy_conflicts              -0.02
# num_big_four_conflicts          0.04
# num_keywords_abstract          -0.03
# num_keywords_title             -0.01
# num_pages                       0.36
# num_sections                    1.00

# %% [markdown]
# ### Random Forest

# %%
X, y = data.iloc[:,0:11], data.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (366, 11)
# (123, 11)
# (366,)
# (123,)

# %%
rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16, random_state=42)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

# %%
rnd_clf.score(X_test, y_test)
# Out:
# 0.6504065040650406

# %% [markdown]
# Using Gridsearch CV

# %%
param_grid = [{'n_estimators': [200,400,500],'max_features':[5,7,9,11]}]

# %%
r_clf = RandomForestClassifier()
grid_search = GridSearchCV(r_clf, param_grid, cv=5,verbose=2)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END ...................max_features=5, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=5, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=5, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=5, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=5, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=5, n_estimators=400; total time=   0.8s
# [CV] END ...................max_features=5, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=5, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=5, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=5, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=5, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=5, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=5, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=5, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=5, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=7, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=7, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=7, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=7, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=7, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=7, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=7, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=7, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=7, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=7, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=7, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=7, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=7, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=7, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=7, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=9, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=9, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=9, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=9, n_estimators=200; total time=   0.3s
# [CV] END ...................max_features=9, n_estimators=200; total time=   0.4s
# [CV] END ...................max_features=9, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=9, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=9, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=9, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=9, n_estimators=400; total time=   0.7s
# [CV] END ...................max_features=9, n_estimators=500; total time=   1.0s
# [CV] END ...................max_features=9, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=9, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=9, n_estimators=500; total time=   0.9s
# [CV] END ...................max_features=9, n_estimators=500; total time=   0.9s
# [CV] END ..................max_features=11, n_estimators=200; total time=   0.3s
# [CV] END ..................max_features=11, n_estimators=200; total time=   0.3s
# [CV] END ..................max_features=11, n_estimators=200; total time=   0.3s
# [CV] END ..................max_features=11, n_estimators=200; total time=   0.3s
# [CV] END ..................max_features=11, n_estimators=200; total time=   0.4s
# [CV] END ..................max_features=11, n_estimators=400; total time=   0.8s
# [CV] END ..................max_features=11, n_estimators=400; total time=   0.8s
# [CV] END ..................max_features=11, n_estimators=400; total time=   0.8s
# [CV] END ..................max_features=11, n_estimators=400; total time=   0.8s
# [CV] END ..................max_features=11, n_estimators=400; total time=   0.8s
# [CV] END ..................max_features=11, n_estimators=500; total time=   1.0s
# [CV] END ..................max_features=11, n_estimators=500; total time=   1.0s
# [CV] END ..................max_features=11, n_estimators=500; total time=   1.0s
# [CV] END ..................max_features=11, n_estimators=500; total time=   1.0s
# [CV] END ..................max_features=11, n_estimators=500; total time=   1.1s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid=[{'max_features': [5, 7, 9, 11],
#                           'n_estimators': [200, 400, 500]}],
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(max_features=5, n_estimators=200)

# %%
grid_search.best_score_
# Out:
# 0.65312847093669

# %% [markdown]
# Now, trying using PCA and using dimension reduction

# %%
pca = PCA()
pca.fit(X_train)
cumsum = np.cumsum(pca.explained_variance_ratio_)
d = np.argmax(cumsum >= 0.998) + 1
d
# cumsum
# Out:
# 5

# %%
plt.figure(figsize=(6,4))
plt.plot(cumsum, linewidth=3)
plt.axis([0, 8, 0, 1.5])
plt.xlabel("Dimensions")
plt.ylabel("Explained Variance")
plt.plot([d, d], [0, 0.998], "k:")
plt.plot([0, d], [0.998, 0.998], "k:")
plt.plot(d, 0.998, "ko")
plt.grid(True)

plt.show()

# %%
pca = PCA(n_components=5)
X_reduced = pca.fit_transform(X_train)

# %%
param_grid = [{'n_estimators': [100,200,300,400,500]}]

# %%
r_clf = RandomForestClassifier()
grid_search = GridSearchCV(r_clf, param_grid, cv=5,verbose=2)
grid_search.fit(X_reduced, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ...................................n_estimators=100; total time=   0.1s
# [CV] END ...................................n_estimators=100; total time=   0.1s
# [CV] END ...................................n_estimators=100; total time=   0.2s
# [CV] END ...................................n_estimators=100; total time=   0.1s
# [CV] END ...................................n_estimators=100; total time=   0.1s
# [CV] END ...................................n_estimators=200; total time=   0.3s
# [CV] END ...................................n_estimators=200; total time=   0.4s
# [CV] END ...................................n_estimators=200; total time=   0.3s
# [CV] END ...................................n_estimators=200; total time=   0.3s
# [CV] END ...................................n_estimators=200; total time=   0.3s
# [CV] END ...................................n_estimators=300; total time=   0.5s
# [CV] END ...................................n_estimators=300; total time=   0.5s
# [CV] END ...................................n_estimators=300; total time=   0.5s
# [CV] END ...................................n_estimators=300; total time=   0.5s
# [CV] END ...................................n_estimators=300; total time=   0.5s
# [CV] END ...................................n_estimators=400; total time=   0.7s
# [CV] END ...................................n_estimators=400; total time=   0.7s
# [CV] END ...................................n_estimators=400; total time=   0.7s
# [CV] END ...................................n_estimators=400; total time=   0.7s
# [CV] END ...................................n_estimators=400; total time=   0.7s
# [CV] END ...................................n_estimators=500; total time=   0.9s
# [CV] END ...................................n_estimators=500; total time=   0.9s
# [CV] END ...................................n_estimators=500; total time=   0.9s
# [CV] END ...................................n_estimators=500; total time=   0.9s
# [CV] END ...................................n_estimators=500; total time=   0.9s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid=[{'n_estimators': [100, 200, 300, 400, 500]}],
#              verbose=2)

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(n_estimators=300)

# %%
grid_search.best_score_
# Out:
# 0.6583117363939281

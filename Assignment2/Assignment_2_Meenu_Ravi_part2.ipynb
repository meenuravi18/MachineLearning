# %% [markdown]
# I met with prof. Igor Sunday and Thursday for some help.

# %% [markdown]
# ### Running Midway

# %% [markdown]
# This is my mobax terminal showing my notebook started using jnc
# I ran everything in the compute node and just used the login node for downloading the iris dataset

# %% [markdown]
# ![img2.png](attachment:img2.png)

# %% [markdown]
# Saving the notebook after running

# %% [markdown]
# ![img3.png](attachment:img3.png)

# %% [markdown]
# Here is a screenshot of the notebook running in Linux OS and info about the path

# %% [markdown]
# ![img4.png](attachment:img4.png)

# %% [markdown]
# I have attached some screenshots showing the run of the notebook- iris dataset I used the login node for

# %% [markdown]
# ![img5.png](attachment:img5.png)

# %% [markdown]
# Another screenshot of notebook runs

# %% [markdown]
# ![img10.png](attachment:img10.png)

# %% [markdown]
# Here you can see I am using the MSCA kernel

# %% [markdown]
# ![img1.png](attachment:img1.png)

# %% [markdown]
# Here is a screenshot of the image directory with the saved plots

# %% [markdown]
# ![img8.png](attachment:img8.png)

# %% [markdown]
# ### Running Skyway with Jupyter

# %% [markdown]
# Here is my batch file: jupyter.sbatch

# %% [markdown]
# ![batch1.png](attachment:batch1.png)

# %% [markdown]
# Batch submission

# %% [markdown]
# ![img11.png](attachment:img11.png)

# %% [markdown]
# Jupyter notebook with AML kernel

# %% [markdown]
# ![img9.png](attachment:img9.png)

# %% [markdown]
# ![img10.png](attachment:img10.png)

# %% [markdown]
# ### Running Skyway from Python file

# %% [markdown]
# Here is my batch file test2.sbatch

# %% [markdown]
# ![batch2.png](attachment:batch2.png)

# %% [markdown]
# Batch submission

# %% [markdown]
# ![img16.png](attachment:img16.png)

# %% [markdown]
# Running the python file:
# - Removed matlab line and used:
# - import matplotlib as mpl
# - mpl.use('Agg')
# Removed the plt.show lines and saved the figures
#
# Added print statement instead of just outputting as you would on jupyter notebook

# %% [markdown]
# Here is a screenshot of my output: the results can be found in slurm-1760.out

# %% [markdown]
# ![img14.png](attachment:img14.png)

# %% [markdown]
# ![img13.png](attachment:img13.png)

# %% [markdown]
# ![img12.png](attachment:img12.png)

# %% [markdown]
# Now I save it as tar file and you can see below my files in the cloud and the tar zip file is in red color

# %% [markdown]
# ![img15.png](attachment:img15.png)

# %% [markdown]
# The slurm-1760.out contain the python output
#
# And images are saved in the images directory
